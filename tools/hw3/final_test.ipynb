# %%
from test_dif_attack import check_solution

# 随机生成密钥进行测试

# %%
check_solution(100, 200)
# Out:
# PASSED  0th test
# PASSED  1th test
# PASSED  2th test
# PASSED  3th test
# PASSED  4th test
# FAILED  5th test
# Random_key :
# 11111101100100000011100000111100
# ans_K :
# ['0111', '1000', '1000', '1100']
# 对应的random_key 后16位:
# ['0011', '1000', '0011', '1100']
# 以上，用来检查哪个出错了
# FAILED  5th test
# Random_key :
# 11111101100100000011100000111100
# ans_K :
# ['0111', '1000', '1000', '1100']
# 对应的random_key 后16位:
# ['0011', '1000', '0011', '1100']
# 以上，用来检查哪个出错了
# PASSED  6th test
# FAILED  7th test
# Random_key :
# 00010110001011101111100001101100
# ans_K :
# ['0011', '1000', '0101', '1100']
# 对应的random_key 后16位:
# ['1111', '1000', '0110', '1100']
# 以上，用来检查哪个出错了
# FAILED  7th test
# Random_key :
# 00010110001011101111100001101100
# ans_K :
# ['0011', '1000', '0101', '1100']
# 对应的random_key 后16位:
# ['1111', '1000', '0110', '1100']
# 以上，用来检查哪个出错了
# PASSED  8th test
# PASSED  9th test
# PASSED  10th test
# PASSED  11th test
# PASSED  12th test
# PASSED  13th test
# PASSED  14th test
# ...

# %%
check_solution(100, 300)
# Out:
# PASSED  0th test
# PASSED  1th test
# PASSED  2th test
# PASSED  3th test
# PASSED  4th test
# PASSED  5th test
# PASSED  6th test
# PASSED  7th test
# PASSED  8th test
# PASSED  9th test
# PASSED  10th test
# PASSED  11th test
# PASSED  12th test
# PASSED  13th test
# PASSED  14th test
# PASSED  15th test
# FAILED  16th test
# Random_key :
# 11001110001101100000011111010100
# ans_K :
# ['1010', '0111', '1101', '0100']
# 对应的random_key 后16位:
# ['0000', '0111', '1101', '0100']
# 以上，用来检查哪个出错了
# PASSED  17th test
# PASSED  18th test
# PASSED  19th test
# PASSED  20th test
# PASSED  21th test
# PASSED  22th test
# PASSED  23th test
# PASSED  24th test
# PASSED  25th test
# PASSED  26th test
# PASSED  27th test
# PASSED  28th test
# PASSED  29th test
# PASSED  30th test
# FAILED  31th test
# Random_key :
# 01000101011001111110011101111110
# ans_K :
# ['0010', '0111', '0111', '1110']
# 对应的random_key 后16位:
# ['1110', '0111', '0111', '1110']
# 以上，用来检查哪个出错了
# PASSED  32th test
# ...

# %%
check_solution(10, 500)
# Out:
# PASSED  0th test
# PASSED  1th test
# PASSED  2th test
# PASSED  3th test
# PASSED  4th test
# PASSED  5th test
# PASSED  6th test
# PASSED  7th test
# PASSED  8th test
# PASSED  9th test
